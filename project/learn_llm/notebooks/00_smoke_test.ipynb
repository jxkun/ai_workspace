# %% [markdown]
# # Notebook 环境验证
#
# 这个 Notebook 用于确认项目内 kernel 可以正常运行。请选择 `Python (learn_llm)` 内核后执行下面的单元格。

# %%
import sys
from pathlib import Path

print(sys.version)
print(sys.executable)
print(Path.cwd())

# %%
import dotenv
import ipykernel

print("python-dotenv:", dotenv.__name__)
print("ipykernel:", ipykernel.__version__)
